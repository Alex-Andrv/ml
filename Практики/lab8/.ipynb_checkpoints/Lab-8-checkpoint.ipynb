# %% [markdown]
# # Курс орнитологии
#
# 1. Реализуйте модель для извлечения признаков из голоса птиц. За основу можно брать:
#    - преобразование в аудиофичи (например как mfcc в лекции. Конкретно это преобразование использовать нельзя)
#    - обученные поверх аудиофич ML модели
#
# 1. С помощью модели и одного из предложенных датасетов создайте эмбеддинги пения птиц. Создайте эмбеддинги нескольких записей каждого вида птиц. Визуализируйте эмбеддинги. Для визуализации рекомендуется использовать подмножество видов птиц
#
# 1. Аргументируйте почему ваша модель хорошо извлекает признаки из аудио.
#     - Покажите кластеризацию эмбеддингов по видам
#
# 1. С помощью эмбеддингов найдите похожие по звучанию виды птиц. Выведите примеры их пения в ноутбуке.
#
#
#
# Датасеты:
# 1. [Датасет](https://www.kaggle.com/vinayshanbhag/bird-song-data-set) американских птиц
# 1. Почищенный от фонового шума BirdCall [датасет](https://www.kaggle.com/luisblanche/birdcall-singing-3)
# 1. [Датасет](https://www.kaggle.com/luisblanche/birdcall-singing-0) BirdCall часть 1

# %%
! pip install librosa
! pip install soundfile
! pip3 install torchaudio
# Out:
# Requirement already satisfied: librosa in c:\python39\lib\site-packages (0.8.1)
# Requirement already satisfied: audioread>=2.0.0 in c:\python39\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in c:\python39\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\python39\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: pooch>=1.0 in c:\python39\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\python39\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numba>=0.43.0 in c:\python39\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\python39\lib\site-packages (from librosa) (1.20.3)
# Requirement already satisfied: joblib>=0.14 in c:\python39\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\python39\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from librosa) (21.0)
# Requirement already satisfied: soundfile>=0.10.2 in c:\python39\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from numba>=0.43.0->librosa) (59.6.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\python39\lib\site-packages (from numba>=0.43.0->librosa) (0.37.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python39\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: requests in c:\python39\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: appdirs in c:\python39\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in c:\python39\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.0.0)
# Requirement already satisfied: cffi>=1.0 in c:\python39\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python39\lib\site-packages (from requests->pooch>=1.0->librosa) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests->pooch>=1.0->librosa) (3.2)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# Requirement already satisfied: soundfile in c:\python39\lib\site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in c:\python39\lib\site-packages (from soundfile) (1.14.6)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0->soundfile) (2.20)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# Requirement already satisfied: torchaudio in c:\python39\lib\site-packages (0.10.0+cu102)
# Requirement already satisfied: torch==1.10.0 in c:\python39\lib\site-packages (from torchaudio) (1.10.0+cu102)
# Requirement already satisfied: typing-extensions in c:\python39\lib\site-packages (from torch==1.10.0->torchaudio) (4.0.1)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -f-nightly (c:\python39\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display as librosa_display
import torchaudio
import torch

# %%
birds = pd.read_csv('bird_songs_metadata.csv')

# %%
birds.head()
# Out:
#        id       genus   species subspecies           name  \
# 0  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 1  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 2  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 3  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 4  557838  Thryomanes  bewickii        NaN  Bewick's Wren
#
#                 recordist        country  \
# 0  Whitney Neufeld-Kaiser  United States
# 1  Whitney Neufeld-Kaiser  United States
# 2  Whitney Neufeld-Kaiser  United States
# 3  Whitney Neufeld-Kaiser  United States
# 4  Whitney Neufeld-Kaiser  United States
#
#                                   location  latitude  longitude altitude  \
# 0  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 1  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 2  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 3  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 4  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
#
#                    sound_type                   source_url  \
# 0  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 1  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 2  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 3  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 4  adult, sex uncertain, song  //www.xeno-canto.org/557838
#
#                                         license   time        date  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
#
#                                              remarks      filename
# 0  Recorded with Voice Record Pro on iPhone7, nor...  557838-0.wav
# 1  Recorded with Voice Record Pro on iPhone7, nor...  557838-1.wav
# 2  Recorded with Voice Record Pro on iPhone7, nor...  557838-4.wav
# 3  Recorded with Voice Record Pro on iPhone7, nor...  557838-5.wav
# 4  Recorded with Voice Record Pro on iPhone7, nor...  557838-6.wav

# %%
birds = birds[['id', 'name', 'filename']]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 10))
plt.hist(birds['name'])
# Out:
# (array([ 893.,    0., 1182.,    0.,    0., 1017.,    0., 1256.,    0.,
#         1074.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
import pickle
from pathlib import Path

# %%
path = Path('wavfiles')

# %%
import os
from tqdm import tqdm

# загрузим датасет небольших речей 6 разных спикеров

speechs = []
for file_name in tqdm(birds['filename']):
    path_ = path / file_name
    
    wave, sample_rate = librosa.load(path_)
    wave, _ = librosa.effects.trim(wave)
    feature = librosa.feature.chroma_cens(y=wave, sr=sample_rate)
    speechs.append(feature)

with open("speechs.txt", "wb") as fp:   #Pickling
    pickle.dump(speechs, fp)
# Out:
#  12%|█▏        | 628/5422 [02:18<17:35,  4.54it/s]c:\python39\lib\site-packages\librosa\core\pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
#  19%|█▉        | 1042/5422 [03:51<16:29,  4.43it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=1010
#   warnings.warn(
#  42%|████▏     | 2261/5422 [08:33<16:33,  3.18it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=938
#   warnings.warn(
#  53%|█████▎    | 2874/5422 [10:53<05:56,  7.14it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=960
#   warnings.warn(
#  58%|█████▊    | 3133/5422 [11:52<05:20,  7.14it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=1008
#   warnings.warn(
#  58%|█████▊    | 3136/5422 [11:52<05:18,  7.19it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=994
#   warnings.warn(
#  81%|████████▏ | 4416/5422 [16:25<02:23,  6.99it/s]c:\python39\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=1024 is too small for input signal of length=906
#   warnings.warn(
# 100%|██████████| 5422/5422 [19:58<00:00,  4.53it/s]

# %%
with open("speechs.txt", "rb") as fp:   # Unpickling
    b = pickle.load(fp)

# %%
speechs = b

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier()

# %%
names = list(set(birds['name']))

# %%
names
# Out:
# ['Song Sparrow',
#  'Northern Cardinal',
#  'Northern Mockingbird',
#  "Bewick's Wren",
#  'American Robin']

# %%
birds['name_id'] = birds['name'].apply(lambda x: names.index(x))

# %%
#X_train, X_test, y_train, y_test = train_test_split(speechs, birds['name'], random_state=42, test_size=0.2)

# %%
birds['speechs'] = speechs

# %%
birds['speechs'] = birds['speechs'].apply(lambda x: x.reshape(np.product(x.shape)))

# %%
birds['len'] = birds['speechs'].apply(lambda x: len(x))

# %%
birds = birds[birds['len'] == 1560]

# %%
from sklearn.utils import shuffle
birds = shuffle(birds)

# %%
type(birds['speechs'][1:10])
# Out:
# pandas.core.series.Series

# %%
birds['name_id']
# Out:
# 952     2
# 3146    0
# 199     3
# 3088    4
# 3806    0
#        ..
# 3768    0
# 296     3
# 716     3
# 3825    0
# 1586    2
# Name: name_id, Length: 5413, dtype: int64

# %%
knn_clf.fit(birds['speechs'].tolist(),birds['name_id'].tolist())
# Out:
# KNeighborsClassifier()

# %%
import umap

embs = umap.UMAP().fit_transform(birds['speechs'][:10].tolist())
# Out:
# c:\python39\lib\site-packages\umap\umap_.py:2344: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(

# %%
plt.figure(figsize=(10,7))
plt.scatter(embs[:, 0], embs[:, 1], c=birds['name_id'][:10], s=70, edgecolor="k")
plt.show()

# %%
# Incorrect number of clusters
y_pred = knn_clf.predict(birds['speechs'][:10].tolist())

# %%
plt.figure(figsize=(10,7))
plt.scatter(embs[:, 0], embs[:, 1], c=y_pred, s=70, edgecolor="k")
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
# Incorrect number of clusters
y_pred = KMeans(n_clusters=5, random_state=42).fit_predict(birds['speechs'].tolist())

# %%
embs = umap.UMAP().fit_transform(birds['speechs'].tolist())

# %%
plt.figure(figsize=(20,30))
plt.scatter(embs[:, 0], embs[:, 1], c=birds['name_id'], s=70, edgecolor="k")
plt.show()

# %%
plt.figure(figsize=(20,30))
plt.scatter(embs[:, 0], embs[:, 1], c=y_pred, s=70, edgecolor="k")
plt.show()

# %%
from scipy.spatial.distance import cdist

# %%
#birds['speechs_lin'] = torch.tensor(birds['speechs_lin'])

# %%
query = birds.loc[10]

# %%
query
# Out:
# id                                                     557838
# name                                            Bewick's Wren
# filename                                        557838-17.wav
# name_id                                                     3
# speechs     [0.2305372661146904, 0.2305405653887818, 0.230...
# len                                                      1560
# Name: 10, dtype: object

# %%
import IPython

# %%
IPython.display.Audio(path / query['filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
birds
# Out:
#           id                  name       filename  name_id  \
# 952   552447  Northern Mockingbird   552447-4.wav        2
# 3146  549591          Song Sparrow   549591-0.wav        0
# 199   351093         Bewick's Wren   351093-8.wav        3
# 3088   13602        American Robin   13602-11.wav        4
# 3806  179182          Song Sparrow   179182-5.wav        0
# ...      ...                   ...            ...      ...
# 3768  193953          Song Sparrow   193953-7.wav        0
# 296   351058         Bewick's Wren   351058-0.wav        3
# 716   173150         Bewick's Wren  173150-11.wav        3
# 3825  149420          Song Sparrow   149420-3.wav        0
# 1586  321894  Northern Mockingbird  321894-15.wav        2
#
#                                                 speechs   len
# 952   [0.0423841856107151, 0.03884775151188226, 0.03...  1560
# 3146  [0.38445567249707324, 0.37328378775759424, 0.3...  1560
# 199   [0.22985463241720736, 0.2290347164405956, 0.22...  1560
# 3088  [0.06637018247433785, 0.06445012459261562, 0.0...  1560
# 3806  [0.4474213098653675, 0.43977990706090203, 0.43...  1560
# ...                                                 ...   ...
# 3768  [0.33918668910158245, 0.3425005009845425, 0.34...  1560
# 296   [0.2794082797293909, 0.27680901649042067, 0.27...  1560
# 716   [0.26958835196991937, 0.2765593906095039, 0.28...  1560
# 3825  [0.22613293938061266, 0.22575391365292205, 0.2...  1560
# 1586  [0.34774296474989924, 0.3469148852801076, 0.34...  1560
#
# [5413 rows x 6 columns]

# %%
birds.loc[0]
# Out:
# id                                                     557838
# name                                            Bewick's Wren
# filename                                         557838-0.wav
# name_id                                                     3
# speechs     [0.22453869088539227, 0.22494374087807, 0.2253...
# len                                                      1560
# Name: 0, dtype: object

# %%
import sklearn
def find_simmilar(query):
    birds['MSE'] = birds.apply(lambda bird: sklearn.metrics.mean_squared_error(bird['speechs'], query['speechs']), axis=1)

# %%
find_simmilar(query)

# %%
birds.sort_values(by=['MSE'], ascending=True, inplace=True)

# %%
birds.head(10)
# Out:
#           id                  name       filename  name_id  \
# 10    557838         Bewick's Wren  557838-17.wav        3
# 0     557838         Bewick's Wren   557838-0.wav        3
# 1877   57040  Northern Mockingbird    57040-9.wav        2
# 993   541496  Northern Mockingbird   541496-8.wav        2
# 992   541496  Northern Mockingbird   541496-7.wav        2
# 2295  464766        American Robin  464766-14.wav        4
# 4     557838         Bewick's Wren   557838-6.wav        3
# 1     557838         Bewick's Wren   557838-1.wav        3
# 1991   18484  Northern Mockingbird    18484-1.wav        2
# 1873   57040  Northern Mockingbird    57040-5.wav        2
#
#                                                 speechs   len       MSE
# 10    [0.2305372661146904, 0.2305405653887818, 0.230...  1560  0.000000
# 0     [0.22453869088539227, 0.22494374087807, 0.2253...  1560  0.000487
# 1877  [0.22180635938210586, 0.22221486403411103, 0.2...  1560  0.008985
# 993   [0.35664154649481467, 0.3533071146470416, 0.34...  1560  0.010841
# 992   [0.23611463672081048, 0.2353979020363294, 0.23...  1560  0.010920
# 2295  [0.22371946006729895, 0.22570466223091298, 0.2...  1560  0.011225
# 4     [0.2318111682618879, 0.2319182008855577, 0.231...  1560  0.011500
# 1     [0.07495413423220985, 0.08262761908604573, 0.0...  1560  0.011512
# 1991  [0.20433576210335896, 0.20195732093614296, 0.2...  1560  0.011680
# 1873  [0.17521770148471455, 0.1803890551865302, 0.18...  1560  0.011894

# %%
ans = birds.iloc[2]

# %%
ans
# Out:
# id                                                      57040
# name                                     Northern Mockingbird
# filename                                          57040-9.wav
# name_id                                                     2
# speechs     [0.22180635938210586, 0.22221486403411103, 0.2...
# len                                                      1560
# MSE                                                  0.008985
# Name: 1877, dtype: object

# %%
IPython.display.Audio(path / ans['filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ans = birds.iloc[3]
IPython.display.Audio(path / ans['filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ans = birds.iloc[5]
IPython.display.Audio(path / ans['filename'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
