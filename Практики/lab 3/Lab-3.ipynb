# %% [markdown]
# # Меня ждут миллионы
#
# Обучите простую модель предсказания цены акций. Используйте один из рассмотренных на лекции "Временные последовательности" алгоритмов предсказания рядов. Можно использовать и более сложные алгоритмы предсказания рядов
#
#
# 1. Найдите данные о цене любого биржевого актива
#
#     Данные должны содержать значение цены актива как минимум за каждый день и длительностю как минимум за год.
#
#     Найти данные можно на kaggle или использовать FAANG датасет из 1 лабораторной
#
#
# 2. Предобработайте данные
#
#     Временной ряд сложно предсказывать по дням. Сделайте ряд по неделям или месяцам
#
#     Удалите из ряда тренд, если он есть. Используйте другие рассмотренные на лекции приёмы
#
#
# 3. Обучите модель
#
#     Обучите модель на 80% временного ряда
#
#     Предскажите оставшиеся 20% (как минимум 3 точки) ряда с помощью модели
#
#     Отобразите на графике предсказание модели и истинные данные
#
#
# 4. Посчитайте метрику
#
#     Метрика должна отражать разницу между предсказанными и истинными данными. Можно выбрать меру MAPE, можно предложить свою

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Source: https://www.statsmodels.org/stable/install.html
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# # Импорт необходимых библиотек
# import copy
# import datetime
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Ford.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1972-06-01  0.000000  2.173495  2.149165  2.153220   0.277407  1091238
# 1  1972-06-02  2.153220  2.173495  2.141055  2.149165   0.276884  1174468
# 2  1972-06-05  2.149165  2.169440  2.141055  2.149165   0.276884  5209582
# 3  1972-06-06  2.149165  2.157275  2.116725  2.124835   0.273750  1424158
# 4  1972-06-07  2.124835  2.137000  2.112670  2.112670   0.272182   675088

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')

df = df.set_index(['Date'])
df.sort_index(inplace=True)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1972-06-01  0.000000  2.173495  2.149165  2.153220   0.277407  1091238
# 1972-06-02  2.153220  2.173495  2.141055  2.149165   0.276884  1174468
# 1972-06-05  2.149165  2.169440  2.141055  2.149165   0.276884  5209582
# 1972-06-06  2.149165  2.157275  2.116725  2.124835   0.273750  1424158
# 1972-06-07  2.124835  2.137000  2.112670  2.112670   0.272182   675088

# %%
df.drop(['Open', 'Low', 'Close', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
df.tail()
# Out:
#                  High
# Date
# 2021-10-18  15.650000
# 2021-10-19  15.690000
# 2021-10-20  16.160000
# 2021-10-21  16.700001
# 2021-10-22  16.540001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12458 entries, 1972-06-01 to 2021-10-22
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   High    12458 non-null  float64
# dtypes: float64(1)
# memory usage: 194.7 KB

# %%
df.isnull().sum()
# Out:
# High    0
# dtype: int64

# %%
# Рассмотрим изменение цены
plt.figure(figsize=(14, 6))
plt.title('Google open price')
plt.xlabel('Date', fontsize=15)
plt.ylabel('Price', rotation=0, labelpad=30, fontsize=15)
df['High'].plot();

# %%
df.shape
# Out:
# (12458, 1)

# %%
df = df.resample("M").mean()
df.shape
# Out:
# (593, 1)

# %%
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose

# Разложим ряд на компоненты и проверим ответы на вопросы

fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(14, 40))
decompose = seasonal_decompose(df[['High']], period=12)

ax[0].set_title('Original')
ax[1].set_title('Trend')
ax[2].set_title('Seasonal')
ax[3].set_title('Residual')

decompose.observed.plot(ax=ax[0])
decompose.trend.plot(ax=ax[1])
decompose.seasonal.plot(ax=ax[2])
decompose.resid.plot(ax=ax[3]);

# %%
p_value = adfuller(df['High'])[1]
print(df['High'])

print(
    f'Полученный уровень значимости (p-value): {round(p_value, 4)}.',
    f'{round(p_value, 4)} > 0.05. Нулевая гипотеза не отвергнута в пользу альтернативной!'
)
# Out:
# Date
# 1972-06-30     2.127047
# 1972-07-31     2.071511
# 1972-08-31     2.171732
# 1972-09-30     2.136392
# 1972-10-31     2.128706
#                 ...
# 2021-06-30    15.420455
# 2021-07-31    14.358095
# 2021-08-31    13.532727
# 2021-09-30    13.486667
# 2021-10-31    15.468750
# Freq: M, Name: High, Length: 593, dtype: float64
# Полученный уровень значимости (p-value): 0.2095. 0.2095 > 0.05. Нулевая гипотеза не отвергнута в пользу альтернативной!

# %% [markdown]
# Попробуем привести ряд к стационарному.

# %%
df['HighLog'] = np.log(df['High'])
plt.figure(figsize=(15, 8))
plt.ylabel('HighLog', rotation=0, labelpad=30)
df['HighLog'].plot();

# %%
p_value = adfuller(df['HighLog'][1:])[1]
print(
    f'Полученный уровень значимости (p-value): {round(p_value, 4)}.',
    f'{round(p_value, 4)} > 0.05. Нулевая гипотеза не отвергнута в пользу альтернативной!'
)
# Out:
# Полученный уровень значимости (p-value): 0.4829. 0.4829 > 0.05. Нулевая гипотеза не отвергнута в пользу альтернативной!

# %%
# Построим коррелограмму и проверим на наличие корреляции
plt.figure(figsize=(15,8))

ax = plt.subplot(211)
statsmodels.graphics.tsaplots.plot_acf(df['HighLogDiffDiff'][13:], lags=60, ax=ax)

ax = plt.subplot(212)
statsmodels.graphics.tsaplots.plot_pacf(df['HighLogDiffDiff'][13:], lags=60, ax=ax);
# Из графиков автокорреляции делаем вывод что ряд не стационарный

# %%
df['HighLogDiff'] = df['HighLog'].diff(12)

plt.figure(figsize=(15, 8))
plt.ylabel('HighLogDiff', rotation=0, labelpad=30)
df['HighLogDiff'].plot();

# %%
p_value = adfuller(df['HighLogDiff'][12:])[1]
print(
    f'Полученный уровень значимости (p-value): {round(p_value, 4)}.',
    f'{round(p_value, 4)} > 0.05. Нулевая гипотеза отвергнута в пользу альтернативной!'
)
# Out:
# Полученный уровень значимости (p-value): 0.0. 0.0 > 0.05. Нулевая гипотеза отвергнута в пользу альтернативной!

# %%
df['HighLogDiffDiff'] = df['HighLogDiff'].diff(1)

plt.figure(figsize=(15, 8))
plt.ylabel('HighLogDiffDiff', rotation=0, labelpad=30)
df['HighLogDiffDiff'].plot();

# %%
p_value = adfuller(df['HighLogDiffDiff'][13:])[1]
print(
    f'Полученный уровень значимости (p-value): {round(p_value, 4)}.',
    f'{round(p_value, 4)} > 0.05. Нулевая гипотеза отвергнута в пользу альтернативной!'
)
# Out:
# Полученный уровень значимости (p-value): 0.0. 0.0 > 0.05. Нулевая гипотеза отвергнута в пользу альтернативной!

# %%
# Построим коррелограмму и проверим на наличие корреляции
plt.figure(figsize=(15,8))

ax = plt.subplot(211)
statsmodels.graphics.tsaplots.plot_acf(df['HighLogDiffDiff'][13:], lags=60, ax=ax)

ax = plt.subplot(212)
statsmodels.graphics.tsaplots.plot_pacf(df['HighLogDiffDiff'][13:], lags=60, ax=ax);
# Из графиков автокорреляции делаем вывод что ряд не стационарный
# Out:
# c:\python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
d=1
D=range(0,2)

qs = range(1, 5)
Qs = range(1, 3)

ps = range(1, 5)
Ps = range(3, 5)

# %%
from itertools import product
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 64

# %%
size = len(df.HighLog)
percentile = int(0.8 * size)

X_train = df['HighLog'][:percentile]
X_test = df['HighLog'][percentile:]
y_train = df['High'][:percentile]
y_test = df['High'][percentile:]

parameters = product(ps, qs, Ps, D, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 128

# %%
import statsmodels.api as sm
from tqdm import tqdm

#warnings.filterwarnings('ignore')

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    try:
        model = sm.tsa.statespace.SARIMAX(
            X_train,
            order=(param[0], d, param[1]),
            seasonal_order=(param[2], param[3], param[4], 6)
        ).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
# Out:
#   1%|          | 1/128 [00:02<05:02,  2.38s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   2%|▏         | 2/128 [00:06<06:52,  3.27s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   2%|▏         | 3/128 [00:11<08:12,  3.94s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   4%|▍         | 5/128 [00:22<09:52,  4.81s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   5%|▍         | 6/128 [00:27<10:02,  4.93s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   5%|▌         | 7/128 [00:34<11:35,  5.75s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   7%|▋         | 9/128 [00:48<11:38,  5.87s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   8%|▊         | 10/128 [00:52<10:22,  5.28s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   9%|▊         | 11/128 [00:57<10:35,  5.43s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#   9%|▉         | 12/128 [01:06<12:04,  6.25s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  10%|█         | 13/128 [01:11<11:14,  5.87s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  11%|█         | 14/128 [01:16<10:54,  5.74s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  12%|█▏        | 15/128 [01:25<12:37,  6.70s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  12%|█▎        | 16/128 [01:36<14:49,  7.94s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  13%|█▎        | 17/128 [01:39<12:20,  6.67s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  14%|█▍        | 18/128 [01:44<11:05,  6.05s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  15%|█▍        | 19/128 [01:50<11:10,  6.15s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  16%|█▌        | 20/128 [01:59<12:30,  6.95s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  16%|█▋        | 21/128 [02:04<11:26,  6.42s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  17%|█▋        | 22/128 [02:11<11:13,  6.35s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  18%|█▊        | 23/128 [02:20<12:54,  7.38s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  19%|█▉        | 24/128 [02:32<15:06,  8.71s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  20%|█▉        | 25/128 [02:36<12:16,  7.15s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  21%|██        | 27/128 [02:42<08:40,  5.16s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  22%|██▏       | 28/128 [02:46<08:06,  4.86s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  23%|██▎       | 29/128 [02:49<07:01,  4.26s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  23%|██▎       | 30/128 [02:52<06:24,  3.93s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  24%|██▍       | 31/128 [02:57<06:57,  4.30s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  25%|██▌       | 32/128 [03:04<08:12,  5.13s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  26%|██▌       | 33/128 [03:06<06:31,  4.12s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  27%|██▋       | 34/128 [03:08<05:26,  3.47s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  27%|██▋       | 35/128 [03:12<05:22,  3.47s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  28%|██▊       | 36/128 [03:17<06:15,  4.08s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  29%|██▉       | 37/128 [03:23<06:53,  4.54s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  30%|██▉       | 38/128 [03:29<07:38,  5.10s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  30%|███       | 39/128 [03:40<10:22,  7.00s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  31%|███▏      | 40/128 [03:55<13:31,  9.22s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  32%|███▏      | 41/128 [03:59<11:09,  7.69s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  33%|███▎      | 42/128 [04:04<09:49,  6.85s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  34%|███▎      | 43/128 [04:11<09:50,  6.95s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  34%|███▍      | 44/128 [04:21<10:53,  7.78s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  35%|███▌      | 45/128 [04:27<10:14,  7.40s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  36%|███▌      | 46/128 [04:35<10:08,  7.42s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  37%|███▋      | 47/128 [04:50<13:03,  9.68s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  38%|███▊      | 48/128 [05:05<15:08, 11.35s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  38%|███▊      | 49/128 [05:10<12:28,  9.47s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  39%|███▉      | 50/128 [05:15<10:42,  8.24s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  40%|███▉      | 51/128 [05:23<10:10,  7.93s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  41%|████      | 52/128 [05:33<10:50,  8.56s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  41%|████▏     | 53/128 [05:41<10:38,  8.51s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  42%|████▏     | 54/128 [05:50<10:37,  8.62s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  43%|████▎     | 55/128 [06:05<12:49, 10.54s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  44%|████▍     | 56/128 [06:24<15:41, 13.08s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  45%|████▍     | 57/128 [06:29<12:37, 10.66s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  45%|████▌     | 58/128 [06:35<10:40,  9.14s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  46%|████▌     | 59/128 [06:42<10:04,  8.76s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  47%|████▋     | 60/128 [06:54<10:43,  9.46s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  48%|████▊     | 61/128 [07:02<10:04,  9.02s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  48%|████▊     | 62/128 [07:10<09:49,  8.93s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  49%|████▉     | 63/128 [07:27<12:16, 11.32s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  50%|█████     | 64/128 [07:48<15:00, 14.06s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  51%|█████     | 65/128 [07:52<11:35, 11.04s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  52%|█████▏    | 66/128 [07:57<09:33,  9.24s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  52%|█████▏    | 67/128 [08:05<09:07,  8.98s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  53%|█████▎    | 68/128 [08:15<09:14,  9.24s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  54%|█████▍    | 69/128 [08:21<08:18,  8.44s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  55%|█████▍    | 70/128 [08:29<08:02,  8.32s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  55%|█████▌    | 71/128 [08:44<09:34, 10.07s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  56%|█████▋    | 72/128 [09:02<11:42, 12.55s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  57%|█████▋    | 73/128 [09:06<09:13, 10.06s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  58%|█████▊    | 74/128 [09:11<07:40,  8.53s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  59%|█████▊    | 75/128 [09:19<07:18,  8.28s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  59%|█████▉    | 76/128 [09:29<07:44,  8.94s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  60%|██████    | 77/128 [09:36<07:05,  8.35s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  61%|██████    | 78/128 [09:44<06:41,  8.02s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  62%|██████▏   | 79/128 [09:59<08:19, 10.19s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  62%|██████▎   | 80/128 [10:18<10:13, 12.79s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  63%|██████▎   | 81/128 [10:23<08:16, 10.57s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  64%|██████▍   | 82/128 [10:29<06:59,  9.13s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  65%|██████▍   | 83/128 [10:36<06:19,  8.44s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  66%|██████▌   | 84/128 [10:46<06:30,  8.89s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  66%|██████▋   | 85/128 [10:53<06:04,  8.48s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  67%|██████▋   | 86/128 [11:01<05:52,  8.39s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  68%|██████▊   | 87/128 [11:17<07:14, 10.60s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  69%|██████▉   | 88/128 [11:36<08:46, 13.17s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  70%|██████▉   | 89/128 [11:41<07:00, 10.77s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  70%|███████   | 90/128 [11:47<05:49,  9.19s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  71%|███████   | 91/128 [11:55<05:28,  8.88s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  72%|███████▏  | 92/128 [12:07<05:49,  9.71s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  73%|███████▎  | 93/128 [12:15<05:27,  9.36s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  73%|███████▎  | 94/128 [12:24<05:10,  9.14s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  74%|███████▍  | 95/128 [12:40<06:10, 11.22s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  76%|███████▌  | 97/128 [13:07<06:03, 11.74s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  77%|███████▋  | 98/128 [13:14<05:04, 10.14s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  77%|███████▋  | 99/128 [13:22<04:34,  9.47s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  78%|███████▊  | 100/128 [13:33<04:40, 10.01s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  79%|███████▉  | 101/128 [13:40<04:06,  9.14s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  80%|███████▉  | 102/128 [13:48<03:48,  8.78s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  80%|████████  | 103/128 [14:04<04:32, 10.91s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  81%|████████▏ | 104/128 [14:27<05:47, 14.50s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  82%|████████▏ | 105/128 [14:32<04:31, 11.80s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  83%|████████▎ | 106/128 [14:38<03:40, 10.02s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  84%|████████▎ | 107/128 [14:46<03:17,  9.38s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  84%|████████▍ | 108/128 [14:58<03:23, 10.17s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  85%|████████▌ | 109/128 [15:06<02:58,  9.39s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  86%|████████▌ | 110/128 [15:14<02:43,  9.06s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  87%|████████▋ | 111/128 [15:31<03:14, 11.42s/it]c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  88%|████████▊ | 112/128 [15:51<03:45, 14.11s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  88%|████████▊ | 113/128 [15:58<02:59, 11.98s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  89%|████████▉ | 114/128 [16:05<02:26, 10.47s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  90%|████████▉ | 115/128 [16:16<02:17, 10.61s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  91%|█████████ | 116/128 [16:29<02:15, 11.29s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  91%|█████████▏| 117/128 [16:38<01:55, 10.51s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  92%|█████████▏| 118/128 [16:48<01:44, 10.42s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  93%|█████████▎| 119/128 [17:09<02:02, 13.58s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  94%|█████████▍| 120/128 [17:32<02:11, 16.46s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  95%|█████████▍| 121/128 [17:38<01:33, 13.41s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  95%|█████████▌| 122/128 [17:45<01:08, 11.45s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  96%|█████████▌| 123/128 [17:57<00:57, 11.45s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  97%|█████████▋| 124/128 [18:12<00:50, 12.60s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  98%|█████████▊| 125/128 [18:22<00:35, 11.68s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  98%|█████████▊| 126/128 [18:33<00:23, 11.51s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  99%|█████████▉| 127/128 [18:52<00:13, 13.85s/it]c:\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 100%|██████████| 128/128 [19:19<00:00,  9.06s/it]

# %%
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#          parameters          aic
# 65  (3, 1, 3, 0, 2) -1011.238736
# 25  (1, 4, 3, 0, 2) -1011.065887
# 68  (3, 1, 4, 0, 1) -1010.819075
# 28  (1, 4, 4, 0, 1) -1010.156343
# 64  (3, 1, 3, 0, 1) -1009.880661

# %%
print(best_model.summary())
# Out:
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                HighLog   No. Observations:                  474
# Model:             SARIMAX(3, 1, 1)x(3, 0, [1, 2], 6)   Log Likelihood                 515.619
# Date:                                Wed, 01 Dec 2021   AIC                          -1011.239
# Time:                                        18:38:39   BIC                           -969.648
# Sample:                                    06-30-1972   HQIC                          -994.880
#                                          - 11-30-2011
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2063      0.187      1.101      0.271      -0.161       0.573
# ar.L2         -0.1157      0.081     -1.427      0.154      -0.275       0.043
# ar.L3          0.1711      0.047      3.635      0.000       0.079       0.263
# ma.L1          0.1493      0.195      0.767      0.443      -0.232       0.531
# ar.S.L6       -0.5640      0.286     -1.972      0.049      -1.124      -0.004
# ar.S.L12      -0.4756      0.292     -1.628      0.104      -1.048       0.097
# ar.S.L18       0.0680      0.073      0.929      0.353      -0.075       0.211
# ma.S.L6        0.4407      0.286      1.542      0.123      -0.119       1.001
# ma.S.L12       0.5146      0.287      1.793      0.073      -0.048       1.077
# sigma2         0.0066      0.000     19.901      0.000       0.006       0.007
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               485.75
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.00   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import numpy as np

y_train_pred = np.exp(best_model.fittedvalues)

plt.figure(figsize=(15,7))

y_train.plot()
y_train_pred.plot(c='r');

# %%
predict_len = size - percentile
y_pred = np.exp(best_model.predict(start=percentile, end=percentile + predict_len - 1))

plt.figure(figsize=(15,7))
df['High'].plot()
y_pred.plot(c='r')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.metrics import mean_absolute_percentage_error

mean_absolute_percentage_error(y_pred, y_test)
# Out:
# 0.25242138834381395
